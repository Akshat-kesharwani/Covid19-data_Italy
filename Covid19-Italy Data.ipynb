# %% [markdown]
# #Covid 19 Data Analysis Italy

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt  #Importing all the necessary libraries

# %%
data = pd.read_csv("C:/Users/aksha/Desktop/Hex Softwares/Task 3/covid19_italy_region.csv") #Import Covid19 dataset from  local Computer

# %% [markdown]
# # Step: 1 Lets Understand the data first

# %%
data.head(10) #To fetch top 10 rows from the data set
# Out:
#    SNo                 Date Country  RegionCode             RegionName  \
# 0    0  2020-02-24T18:00:00     ITA          13                Abruzzo
# 1    1  2020-02-24T18:00:00     ITA          17             Basilicata
# 2    2  2020-02-24T18:00:00     ITA          18               Calabria
# 3    3  2020-02-24T18:00:00     ITA          15               Campania
# 4    4  2020-02-24T18:00:00     ITA           8         Emilia-Romagna
# 5    5  2020-02-24T18:00:00     ITA           6  Friuli Venezia Giulia
# 6    6  2020-02-24T18:00:00     ITA          12                  Lazio
# 7    7  2020-02-24T18:00:00     ITA           7                Liguria
# 8    8  2020-02-24T18:00:00     ITA           3              Lombardia
# 9    9  2020-02-24T18:00:00     ITA          11                 Marche
#
#     Latitude  Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0  42.351222  13.398438                     0                      0
# ...

# %%
data.tail(10)  # To fetch last 10 rows from the dataset
# Out:
#        SNo                 Date Country  RegionCode     RegionName   Latitude  \
# 6017  6017  2020-12-06T17:00:00     ITA          21   P.A. Bolzano  46.499335
# 6018  6018  2020-12-06T17:00:00     ITA          22    P.A. Trento  46.068935
# 6019  6019  2020-12-06T17:00:00     ITA           1       Piemonte  45.073274
# 6020  6020  2020-12-06T17:00:00     ITA          16         Puglia  41.125596
# 6021  6021  2020-12-06T17:00:00     ITA          20       Sardegna  39.215312
# 6022  6022  2020-12-06T17:00:00     ITA          19        Sicilia  38.115697
# 6023  6023  2020-12-06T17:00:00     ITA           9        Toscana  43.769231
# 6024  6024  2020-12-06T17:00:00     ITA          10         Umbria  43.106758
# 6025  6025  2020-12-06T17:00:00     ITA           2  Valle d'Aosta  45.737503
# 6026  6026  2020-12-06T17:00:00     ITA           5         Veneto  45.434905
#
#       Longitude  HospitalizedPatients  IntensiveCarePatients  \
# ...

# %%
data.columns #To Check all the Columns inside the dataset
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
data.describe() #To retrive all the stastictics from the dataset
# Out:
#                SNo   RegionCode     Latitude    Longitude  \
# count  6027.000000  6027.000000  6027.000000  6027.000000
# mean   3013.000000    11.857143    43.046293    12.225955
# std    1739.989368     6.274319     2.488987     2.659168
# min       0.000000     1.000000    38.115697     7.320149
# 25%    1506.500000     7.000000    41.125596    11.121231
# 50%    3013.000000    12.000000    43.616760    12.388247
# 75%    4519.500000    17.000000    45.434905    13.768136
# max    6026.000000    22.000000    46.499335    16.867367
#
#        HospitalizedPatients  IntensiveCarePatients  TotalHospitalizedPatients  \
# count           6027.000000            6027.000000                6027.000000
# mean             509.093579              55.892318                 564.985897
# std             1272.731157             134.957979                1403.362341
# min                0.000000               0.000000                   0.000000
# ...

# %% [markdown]
# #Step  2 Cleaning the data

# %%
data.isnull().sum()  #here we can see the we dont have any Null Values in the data 
                     # Except TestPerformed Row : 1155 Nul Values
# Out:
# SNo                             0
# Date                            0
# Country                         0
# RegionCode                      0
# RegionName                      0
# Latitude                        0
# Longitude                       0
# HospitalizedPatients            0
# IntensiveCarePatients           0
# TotalHospitalizedPatients       0
# HomeConfinement                 0
# CurrentPositiveCases            0
# NewPositiveCases                0
# Recovered                       0
# Deaths                          0
# TotalPositiveCases              0
# TestsPerformed               1155
# dtype: int64

# %%
data = data.dropna()

# Remove rows where 'TestsPerformed' is null

# %%
data.isnull().sum() #now recheck and see that the Null values from the row TestPerformed has been removed
# Out:
# SNo                          0
# Date                         0
# Country                      0
# RegionCode                   0
# RegionName                   0
# Latitude                     0
# Longitude                    0
# HospitalizedPatients         0
# IntensiveCarePatients        0
# TotalHospitalizedPatients    0
# HomeConfinement              0
# CurrentPositiveCases         0
# NewPositiveCases             0
# Recovered                    0
# Deaths                       0
# TotalPositiveCases           0
# TestsPerformed               0
# dtype: int64

# %%
data.nunique()  #To check the Unique Values in the dataset
# Out:
# SNo                          4872
# Date                          232
# Country                         1
# RegionCode                     21
# RegionName                     21
# Latitude                       21
# Longitude                      21
# HospitalizedPatients         1212
# IntensiveCarePatients         375
# TotalHospitalizedPatients    1278
# HomeConfinement              2907
# CurrentPositiveCases         2988
# NewPositiveCases             1008
# Recovered                    3822
# Deaths                       1852
# TotalPositiveCases           3989
# TestsPerformed               4835
# dtype: int64

# %%
# Step 3 Data Visualization 
# Relationship Analysis

# %% [markdown]
# # Number of PositiveCases , Death , Recovered . By Region names in Italy

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
sns.relplot( x = 'TotalPositiveCases' , y  = 'RegionName' , kind = 'line' , data = data) #Lets start with analyzing Relationship between  Number of Regions and Total positive cases

# %%
sns.relplot( x = 'Deaths' , y  = 'RegionName' , kind = 'line' , data = data) #Total Deaths vs Regions in Italy

# %%
sns.relplot( x = 'Recovered' , y  = 'RegionName' , kind = 'line' , data = data) #No.of People Recovered by Region Name of Italy

# %% [markdown]
# # Analysis for Whole Country Italy

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
sns.relplot( x = "TotalHospitalizedPatients", y = "Recovered", data = data)  # Here we will use Scatterplot to check the 
                                                                           #Relatoinship of TotalHospiltlizedPatients vs Recovered patients

# %%
sns.relplot( x = "TotalPositiveCases", y = "Deaths", data = data) # Here we observer the relationship between TotalPositive cases vs Total Deaths

# %%
sns.pairplot(data)  #Complete data analysis

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
sns.relplot( x = 'CurrentPositiveCases' , y  = 'HomeConfinement' , kind = 'line' , data = data) #Realtionship between CurrentPositiveCases vs HomeQurantined People

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
sns.catplot( x = "TotalPositiveCases", y = "Recovered", data = data) #Relationship between Total Positive Cases vs number of people who Recovered
